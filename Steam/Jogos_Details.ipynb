# %%
from steam_web_api import Steam

KEY = "1A1F4922939AFD7DFB99B30C31BCE24F"
steam = Steam(KEY)

user = steam.users.get_owned_games("76561198991169245")
print(user)

game = steam.apps.get_app_details(105600)
print(game)

search = steam.apps.search_games("105600")
print(search)
# Out:
# {'game_count': 20, 'games': [{'appid': 4700, 'name': 'Total War: MEDIEVAL II - Definitive Edition', 'playtime_forever': 999, 'img_icon_url': 'cc9c44b2c3b3b245b82d13c316a9b238705ff877', 'playtime_windows_forever': 999, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1693270855, 'content_descriptorids': [2, 5], 'playtime_disconnected': 0}, {'appid': 4760, 'name': 'Rome: Total War', 'playtime_forever': 46007, 'img_icon_url': '5dc68565149dc971af6428157bcb600d80690080', 'playtime_windows_forever': 46007, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1670092988, 'playtime_disconnected': 0}, {'appid': 4770, 'name': 'Rome: Total War - Alexander', 'playtime_forever': 6, 'img_icon_url': '609a824446a556878febbc3aa0be7d1f9b92a4fb', 'playtime_windows_forever': 6, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1588639205, 'content_descriptorids': [2, 5], 'playtime_disconnected': 0}, {'appid': 214950, 'name': 'Total War: ROME II - Emperor Edition', 'playtime_2weeks': 317, 'playtime_forever': 29308, 'img_icon_url': '08ae0b3454bfe8e7ae9038331b27629667119a24', 'has_community_visible_stats': True, 'playtime_windows_forever': 29308, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1713403786, 'playtime_disconnected': 0}, {'appid': 271590, 'name': 'Grand Theft Auto V', 'playtime_forever': 3668, 'img_icon_url': '1e72f87eb927fa1485e68aefaff23c7fd7178251', 'has_community_visible_stats': True, 'playtime_windows_forever': 3668, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1705625819, 'content_descriptorids': [5], 'playtime_disconnected': 1}, {'appid': 431960, 'name': 'Wallpaper Engine', 'playtime_forever': 7, 'img_icon_url': '72edaed9d748c6cf7397ffb1c83f0b837b9ebd9d', 'has_community_visible_stats': True, 'playtime_windows_forever': 7, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1709374953, 'playtime_disconnected': 0}, {'appid': 266840, 'name': 'Age of Mythology: Extended Edition', 'playtime_forever': 213, 'img_icon_url': '43e500d938e87b623c11a02d7b80f7e9018fbbd7', 'has_community_visible_stats': True, 'playtime_windows_forever': 213, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1688907686, 'has_leaderboards': True, 'playtime_disconnected': 0}, {'appid': 275850, 'name': "No Man's Sky", 'playtime_forever': 386, 'img_icon_url': 'fccb20f309ac5ae05b3cb4576a8a3357edf86f2e', 'has_community_visible_stats': True, 'playtime_windows_forever': 386, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1693769708, 'playtime_disconnected': 0}, {'appid': 220240, 'name': 'Far Cry® 3', 'playtime_forever': 0, 'img_icon_url': '8231f43d3dd47fb4b4111fd6bd4a849e73eb0520', 'playtime_windows_forever': 0, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 0, 'playtime_disconnected': 0}, {'appid': 552520, 'name': 'Far Cry 5', 'playtime_forever': 0, 'img_icon_url': '928df2d32021f480499a97458068f62c45298e7a', 'playtime_windows_forever': 0, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 0, 'playtime_disconnected': 0}, {'appid': 933110, 'name': 'Age of Empires III: Definitive Edition', 'playtime_forever': 215, 'img_icon_url': '145e4d6278f545ea3300d777e2dc3c56ddbbcc5c', 'has_community_visible_stats': True, 'playtime_windows_forever': 215, 'playtime_mac_forever': 0, 'playtime_linux_forever': 0, 'playtime_deck_forever': 0, 'rtime_last_played': 1686419225, 'playtime_disconnected': 0}, {'appid': 730, 'name': 'Counter-Strike 2', 'playtime_forever': 62, 'img_icon_url': '8dbc71957312bbd3baea65848b545be9eae2a355', 'has_community ...
# {'105600': {'success': True, 'data': {'type': 'game', 'name': 'Terraria', 'steam_appid': 105600, 'required_age': 0, 'is_free': False, 'controller_support': 'full', 'dlc': [409210, 1323320], 'detailed_description': 'Dig, Fight, Explore, Build:  The very world is at your fingertips as you fight for survival, fortune, and glory.   Will you delve deep into cavernous expanses in search of treasure and raw materials with which to craft ever-evolving gear, machinery, and aesthetics?   Perhaps you will choose instead to seek out ever-greater foes to test your mettle in combat?   Maybe you will decide to construct your own city to house the host of mysterious allies you may encounter along your travels? <br><br>In the World of Terraria, the choice is yours!<br><br>Blending elements of classic action games with the freedom of sandbox-style creativity, Terraria is a unique gaming experience where both the journey and the destination are completely in the player’s control.   The Terraria adventure is truly as unique as the players themselves!  <br><br>Are you up for the monumental task of exploring, creating, and defending a world of your own?  <br><br>\t\t\t\t\t\t\t<strong>Key features:</strong><br>\t\t\t\t\t\t\t<ul class="bb_ul"><li>Sandbox Play<br>\t\t\t\t\t\t\t</li><li> Randomly generated worlds<br>\t\t\t\t\t\t\t</li><li>Free Content Updates<br>\t\t\t\t\t\t\t</li></ul>', 'about_the_game': 'Dig, Fight, Explore, Build:  The very world is at your fingertips as you fight for survival, fortune, and glory.   Will you delve deep into cavernous expanses in search of treasure and raw materials with which to craft ever-evolving gear, machinery, and aesthetics?   Perhaps you will choose instead to seek out ever-greater foes to test your mettle in combat?   Maybe you will decide to construct your own city to house the host of mysterious allies you may encounter along your travels? <br><br>In the World of Terraria, the choice is yours!<br><br>Blending elements of classic action games with the freedom of sandbox-style creativity, Terraria is a unique gaming experience where both the journey and the destination are completely in the player’s control.   The Terraria adventure is truly as unique as the players themselves!  <br><br>Are you up for the monumental task of exploring, creating, and defending a world of your own?  <br><br>\t\t\t\t\t\t\t<strong>Key features:</strong><br>\t\t\t\t\t\t\t<ul class="bb_ul"><li>Sandbox Play<br>\t\t\t\t\t\t\t</li><li> Randomly generated worlds<br>\t\t\t\t\t\t\t</li><li>Free Content Updates<br>\t\t\t\t\t\t\t</li></ul>', 'short_description': 'Dig, fight, explore, build! Nothing is impossible in this action-packed adventure game. Four Pack also available!', 'supported_languages': 'English, French, Italian, German, Spanish - Spain, Polish, Portuguese - Brazil, Russian, Simplified Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/105600/header.jpg?t=1666290860', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/105600/capsule_231x87.jpg?t=1666290860', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/105600/capsule_184x69.jpg?t=1666290860', 'website': 'http://www.terraria.org/', 'pc_requirements': {'minimum': '<h2 class="bb_tag"><strong>REQUIRED</strong></h2><ul class="bb_ul"><li><strong>OS: Windows Xp, Vista, 7, 8/8.1, 10</strong> <br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>Processor: 2.0 Ghz</strong> <br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>Memory: 2.5GB</strong><br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>Hard Disk Space: 200MB </strong> \t<br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>Video Card: 128mb Video Memory, capable of Shader Model 2.0+</strong> <br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>DirectX®: 9.0c or Greater</strong> \t<br>\t\t\t\t\t\t\t\t\t</li></ul>', 'recommended': '<h2 class="bb_tag"><strong>RECOMMENDED</strong></h2><ul class="bb_ul"><li><strong>OS: Windows 7, 8/8.1, 10</strong> <br>\t\t\t\t\t\t\t\t\t\t</li><li><strong>Processor: Dual Core 3.0 Ghz</strong> <br>\t ...
# {'apps': [{'id': [105600], 'link': 'https://store.steampowered.com/app/105600/Terraria/?snr=1_7_15__13', 'name': 'Terraria', 'img': 'https://cdn.cloudflare.steamstatic.com/steam/apps/105600/capsule_sm_120.jpg?t=1666290860', 'price': '$9.99'}]}

# %%
# Começar com um ID alto e trabalhar para baixo
current_app_id = 100  # Comece com um ID alto
last_valid_app_id = 0
batch_size = 1  # Quantidade de IDs para verificar de uma vez

# Lista para armazenar os detalhes dos aplicativos válidos
app_details_list = []

while True:
    # Verificar um lote de IDs de aplicativos
    app_details_batch = steam.apps.get_app_details(current_app_id - batch_size, current_app_id)
    
    # Verificar se os detalhes do aplicativo foram retornados
    if app_details_batch:
        # Verificar cada ID de aplicativo no lote
        for app_id, details in app_details_batch.items():
            if 'success' in details and not details['success']:
                # ID não existe, continue para o próximo ID
                continue
            if details:
                last_valid_app_id = app_id
                app_details_list.append(details)  # Adicionar detalhes à lista
                print(steam.apps.get_app_details(last_valid_app_id))
    else:
        # Nenhum detalhe de aplicativo retornado, então provavelmente atingimos o último ID válido
        break
    
    # Atualizar o ID atual para o próximo lote
    current_app_id -= batch_size

print(f"Último ID válido: {last_valid_app_id}")
# Out:
# {'92': {'success': True, 'data': {'type': 'advertising', 'name': 'Codename Gordon', 'steam_appid': 92, 'required_age': 0, 'is_free': False, 'detailed_description': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'about_the_game': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'short_description': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'supported_languages': 'English', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/92/header.jpg?t=1447350816', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/92/capsule_231x87.jpg?t=1447350816', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/92/capsule_184x69.jpg?t=1447350816', 'website': None, 'pc_requirements': [], 'mac_requirements': [], 'linux_requirements': []}}}
# {'80': {'success': True, 'data': {'type': 'game', 'name': 'Counter-Strike: Condition Zero', 'steam_appid': 80, 'required_age': 0, 'is_free': False, 'detailed_description': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'about_the_game': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'short_description': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Simplified Chinese, Traditional Chinese, Korean', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/80/header.jpg?t=1602535977', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/80/capsule_231x87.jpg?t=1602535977', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/80/capsule_184x69.jpg?t=1602535977', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': [], 'linux_requirements': []}}}
# {'70': {'success': True, 'data': {'type': 'game', 'name': 'Half-Life', 'steam_appid': 70, 'required_age': 0, 'is_free': False, 'controller_support': 'full', 'dlc': [323130], 'detailed_description': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'about_the_game': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'short_description': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'supported_languages': 'English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/70/header.jpg?t=1700269108', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/70/capsule_231x87.jpg?t=1700269108', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/70/capsule_184x69.jpg?t=1700269108', 'website': 'http://www.half-life.com/', 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'60': {'success': True, 'data': {'type': 'game', 'name': 'Ricochet', 'steam_appid': 60, 'required_age': 0, 'is_free': False, 'detailed_description': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'about_the_game': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'short_description': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/60/header.jpg?t=1599518374', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/60/capsule_231x87.jpg?t=1599518374', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/60/capsule_184x69.jpg?t=1599518374', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'50': {'success': True, 'data': {'type': 'game', 'name': 'Half-Life: Opposing Force', 'steam_appid': 50, 'required_age': 0, 'is_free': False, 'detailed_description': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'about_the_game': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'short_description': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'supported_languages': 'English, French, German, Korean', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/50/header.jpg?t=1579628243', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/50/capsule_231x87.jpg?t=1579628243', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/50/capsule_184x69.jpg?t=1579628243', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'40': {'success': True, 'data': {'type': 'game', 'name': 'Deathmatch Classic', 'steam_appid': 40, 'required_age': 0, 'is_free': False, 'detailed_description': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'about_the_game': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'short_description': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/40/header.jpg?t=1568752159', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/40/capsule_231x87.jpg?t=1568752159', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/40/capsule_184x69.jpg?t=1568752159', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'30': {'success': True, 'data': {'type': 'game', 'name': 'Day of Defeat', 'steam_appid': 30, 'required_age': 0, 'is_free': False, 'detailed_description': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations. And, as war rages, players must work together with their squad to accomplish a variety of mission-specific objectives.', 'about_the_game': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations. And, as war rages, players must work together with their squad to accomplish a variety of mission-specific objectives.', 'short_description': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/30/header.jpg?t=1512413490', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/30/capsule_231x87.jpg?t=1512413490', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/30/capsule_184x69.jpg?t=1512413490', 'website': 'http://www.dayofdefeat.com/', 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'20': {'success': True, 'data': {'type': 'game', 'name': 'Team Fortress Classic', 'steam_appid': 20, 'required_age': 0, 'is_free': False, 'detailed_description': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'about_the_game': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'short_description': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/20/header.jpg?t=1579634708', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/20/capsule_231x87.jpg?t=1579634708', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/20/capsule_184x69.jpg?t=1579634708', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'10': {'success': True, 'data': {'type': 'game', 'name': 'Counter-Strike', 'steam_appid': 10, 'required_age': 0, 'is_free': False, 'detailed_description': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'about_the_game': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'short_description': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'supported_languages': 'English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/10/header.jpg?t=1666823513', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/10/capsule_231x87.jpg?t=1666823513', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/10/capsule_184x69.jpg?t=1666823513', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# Último ID válido: 10

# %%
import pandas as pd

# Converter a lista de detalhes dos aplicativos em um DataFrame do pandas
df = pd.DataFrame(app_details_list)

# Exibir o DataFrame
print(df)
# Out:
#    success                                               data
# 0     True  {'type': 'advertising', 'name': 'Codename Gord...
# 1     True  {'type': 'game', 'name': 'Counter-Strike: Cond...
# 2     True  {'type': 'game', 'name': 'Half-Life', 'steam_a...
# 3     True  {'type': 'game', 'name': 'Ricochet', 'steam_ap...
# 4     True  {'type': 'game', 'name': 'Half-Life: Opposing ...
# 5     True  {'type': 'game', 'name': 'Deathmatch Classic',...
# 6     True  {'type': 'game', 'name': 'Day of Defeat', 'ste...
# 7     True  {'type': 'game', 'name': 'Team Fortress Classi...
# 8     True  {'type': 'game', 'name': 'Counter-Strike', 'st...

# %%
import pandas as pd

# Começar com um ID alto e trabalhar para baixo
current_app_id = 100  # Comece com um ID alto
last_valid_app_id = 0
batch_size = 1  # Quantidade de IDs para verificar de uma vez

# Lista para armazenar os detalhes dos aplicativos válidos
app_details_list = []

while True:
    # Verificar um lote de IDs de aplicativos
    app_details_batch = steam.apps.get_app_details(current_app_id - batch_size, current_app_id)
    
    # Verificar se os detalhes do aplicativo foram retornados
    if app_details_batch:
        # Verificar cada ID de aplicativo no lote
        for app_id, details in app_details_batch.items():
            if 'success' in details and not details['success']:
                # ID não existe, continue para o próximo ID
                continue
            if details:
                last_valid_app_id = app_id
                app_details_list.append(details)  # Adicionar detalhes à lista
                print(steam.apps.get_app_details(last_valid_app_id))
    else:
        # Nenhum detalhe de aplicativo retornado, então provavelmente atingimos o último ID válido
        break
    
    # Atualizar o ID atual para o próximo lote
    current_app_id -= batch_size

print(f"Último ID válido: {last_valid_app_id}")

# Converter a lista de detalhes dos aplicativos em um DataFrame do pandas
df = pd.DataFrame(app_details_list)

# Expandir o dicionário aninhado dentro da coluna 'data' em colunas separadas
df_expanded = pd.json_normalize(df['data'])

# Combinar o DataFrame original com o DataFrame expandido
df_final = pd.concat([df[['success']], df_expanded], axis=1)

# Exibir o DataFrame final
print(df_final)
# Out:
# {'92': {'success': True, 'data': {'type': 'advertising', 'name': 'Codename Gordon', 'steam_appid': 92, 'required_age': 0, 'is_free': False, 'detailed_description': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'about_the_game': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'short_description': 'Created by Nuclearvision Entertainment, Codename Gordon takes players through dozens of levels inspired by Half-Life and Half-Life 2, challenges players to a slew of puzzles, and showcases many of the familiar creatures in an all new, 2 dimensional playing field.', 'supported_languages': 'English', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/92/header.jpg?t=1447350816', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/92/capsule_231x87.jpg?t=1447350816', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/92/capsule_184x69.jpg?t=1447350816', 'website': None, 'pc_requirements': [], 'mac_requirements': [], 'linux_requirements': []}}}
# {'80': {'success': True, 'data': {'type': 'game', 'name': 'Counter-Strike: Condition Zero', 'steam_appid': 80, 'required_age': 0, 'is_free': False, 'detailed_description': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'about_the_game': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'short_description': "With its extensive Tour of Duty campaign, a near-limitless number of skirmish modes, updates and new content for Counter-Strike's award-winning multiplayer game play, plus over 12 bonus single player missions, Counter-Strike: Condition Zero is a tremendous offering of single and multiplayer content.", 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Simplified Chinese, Traditional Chinese, Korean', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/80/header.jpg?t=1602535977', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/80/capsule_231x87.jpg?t=1602535977', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/80/capsule_184x69.jpg?t=1602535977', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': [], 'linux_requirements': []}}}
# {'70': {'success': True, 'data': {'type': 'game', 'name': 'Half-Life', 'steam_appid': 70, 'required_age': 0, 'is_free': False, 'controller_support': 'full', 'dlc': [323130], 'detailed_description': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'about_the_game': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'short_description': "Named Game of the Year by over 50 publications, Valve's debut title blends action and adventure with award-winning technology to create a frighteningly realistic world where players must think to survive. Also includes an exciting multiplayer mode that allows you to play against friends and enemies around the world.", 'supported_languages': 'English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/70/header.jpg?t=1700269108', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/70/capsule_231x87.jpg?t=1700269108', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/70/capsule_184x69.jpg?t=1700269108', 'website': 'http://www.half-life.com/', 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'60': {'success': True, 'data': {'type': 'game', 'name': 'Ricochet', 'steam_appid': 60, 'required_age': 0, 'is_free': False, 'detailed_description': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'about_the_game': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'short_description': 'A futuristic action game that challenges your agility as well as your aim, Ricochet features one-on-one and team matches played in a variety of futuristic battle arenas.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/60/header.jpg?t=1599518374', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/60/capsule_231x87.jpg?t=1599518374', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/60/capsule_184x69.jpg?t=1599518374', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'50': {'success': True, 'data': {'type': 'game', 'name': 'Half-Life: Opposing Force', 'steam_appid': 50, 'required_age': 0, 'is_free': False, 'detailed_description': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'about_the_game': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'short_description': "Return to the Black Mesa Research Facility as one of the military specialists assigned to eliminate Gordon Freeman. Experience an entirely new episode of single player action. Meet fierce alien opponents, and experiment with new weaponry. Named 'Game of the Year' by the Academy of Interactive Arts and Sciences.", 'supported_languages': 'English, French, German, Korean', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/50/header.jpg?t=1579628243', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/50/capsule_231x87.jpg?t=1579628243', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/50/capsule_184x69.jpg?t=1579628243', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'40': {'success': True, 'data': {'type': 'game', 'name': 'Deathmatch Classic', 'steam_appid': 40, 'required_age': 0, 'is_free': False, 'detailed_description': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'about_the_game': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'short_description': "Enjoy fast-paced multiplayer gaming with Deathmatch Classic (a.k.a. DMC). Valve's tribute to the work of id software, DMC invites players to grab their rocket launchers and put their reflexes to the test in a collection of futuristic settings.", 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/40/header.jpg?t=1568752159', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/40/capsule_231x87.jpg?t=1568752159', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/40/capsule_184x69.jpg?t=1568752159', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'30': {'success': True, 'data': {'type': 'game', 'name': 'Day of Defeat', 'steam_appid': 30, 'required_age': 0, 'is_free': False, 'detailed_description': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations. And, as war rages, players must work together with their squad to accomplish a variety of mission-specific objectives.', 'about_the_game': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations. And, as war rages, players must work together with their squad to accomplish a variety of mission-specific objectives.', 'short_description': 'Enlist in an intense brand of Axis vs. Allied teamplay set in the WWII European Theatre of Operations. Players assume the role of light/assault/heavy infantry, sniper or machine-gunner class, each with a unique arsenal of historical weaponry at their disposal. Missions are based on key historical operations.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/30/header.jpg?t=1512413490', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/30/capsule_231x87.jpg?t=1512413490', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/30/capsule_184x69.jpg?t=1512413490', 'website': 'http://www.dayofdefeat.com/', 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'20': {'success': True, 'data': {'type': 'game', 'name': 'Team Fortress Classic', 'steam_appid': 20, 'required_age': 0, 'is_free': False, 'detailed_description': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'about_the_game': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'short_description': 'One of the most popular online action games of all time, Team Fortress Classic features over nine character classes -- from Medic to Spy to Demolition Man -- enlisted in a unique style of online team warfare. Each character class possesses unique weapons, items, and abilities, as teams compete online in a variety of game play modes.', 'supported_languages': 'English, French, German, Italian, Spanish - Spain, Korean, Russian, Simplified Chinese, Traditional Chinese', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/20/header.jpg?t=1579634708', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/20/capsule_231x87.jpg?t=1579634708', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/20/capsule_184x69.jpg?t=1579634708', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# {'10': {'success': True, 'data': {'type': 'game', 'name': 'Counter-Strike', 'steam_appid': 10, 'required_age': 0, 'is_free': False, 'detailed_description': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'about_the_game': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'short_description': "Play the world's number 1 online action game. Engage in an incredibly realistic brand of terrorist warfare in this wildly popular team-based game. Ally with teammates to complete strategic missions. Take out enemy sites. Rescue hostages. Your role affects your team's success. Your team's success affects your role.", 'supported_languages': 'English<strong>*</strong>, French<strong>*</strong>, German<strong>*</strong>, Italian<strong>*</strong>, Spanish - Spain<strong>*</strong>, Simplified Chinese<strong>*</strong>, Traditional Chinese<strong>*</strong>, Korean<strong>*</strong><br><strong>*</strong>languages with full audio support', 'header_image': 'https://cdn.akamai.steamstatic.com/steam/apps/10/header.jpg?t=1666823513', 'capsule_image': 'https://cdn.akamai.steamstatic.com/steam/apps/10/capsule_231x87.jpg?t=1666823513', 'capsule_imagev5': 'https://cdn.akamai.steamstatic.com/steam/apps/10/capsule_184x69.jpg?t=1666823513', 'website': None, 'pc_requirements': {'minimum': '\r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz processor, 96mb ram, 16mb video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t<p><strong>Recommended:</strong> 800 mhz processor, 128mb ram, 32mb+ video card, Windows XP, Mouse, Keyboard, Internet Connection<br /></p>\r\n\t\t\t'}, 'mac_requirements': {'minimum': 'Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4GB Hard Drive Space,NVIDIA GeForce 8 or higher, ATI X1600 or higher, or Intel HD 3000 or higher Mouse, Keyboard, Internet Connection'}, 'linux_requirements': {'minimum': 'Minimum: Linux Ubuntu 12.04, Dual-core from Intel or AMD at 2.8 GHz, 1GB Memory, nVidia GeForce 8600/9600GT, ATI/AMD Radeaon HD2600/3600 (Graphic Drivers: nVidia 310, AMD 12.11), OpenGL 2.1, 4GB Hard Drive Space, OpenAL Compatible Sound Card'}}}}
# Último ID válido: 10
#    success         type                            name  steam_appid  \
# 0     True  advertising                 Codename Gordon           92
# 1     True         game  Counter-Strike: Condition Zero           80
# 2     True         game                       Half-Life           70
# 3     True         game                        Ricochet           60
# 4     True         game       Half-Life: Opposing Force           50
# 5     True         game              Deathmatch Classic           40
# 6     True         game                   Day of Defeat           30
# 7     True         game           Team Fortress Classic           20
# 8     True         game                  Counter-Strike           10
#
#    required_age  is_free                               detailed_description  \
# 0             0    False  Created by Nuclearvision Entertainment, Codena...
# 1             0    False  With its extensive Tour of Duty campaign, a ne...
# 2             0    False  Named Game of the Year by over 50 publications...
# 3             0    False  A futuristic action game that challenges your ...
# 4             0    False  Return to the Black Mesa Research Facility as ...
# 5             0    False  Enjoy fast-paced multiplayer gaming with Death...
# 6             0    False  Enlist in an intense brand of Axis vs. Allied ...
# 7             0    False  One of the most popular online action games of...
# 8             0    False  Play the world's number 1 online action game. ...
#
#                                       about_the_game  \
# 0  Created by Nuclearvision Entertainment, Codena...
# 1  With its extensive Tour of Duty campaign, a ne...
# 2  Named Game of the Year by over 50 publications...
# 3  A futuristic action game that challenges your ...
# 4  Return to the Black Mesa Research Facility as ...
# 5  Enjoy fast-paced multiplayer gaming with Death...
# 6  Enlist in an intense brand of Axis vs. Allied ...
# 7  One of the most popular online action games of...
# 8  Play the world's number 1 online action game. ...
#
#                                    short_description  \
# 0  Created by Nuclearvision Entertainment, Codena...
# 1  With its extensive Tour of Duty campaign, a ne...
# 2  Named Game of the Year by over 50 publications...
# 3  A futuristic action game that challenges your ...
# 4  Return to the Black Mesa Research Facility as ...
# 5  Enjoy fast-paced multiplayer gaming with Death...
# 6  Enlist in an intense brand of Axis vs. Allied ...
# 7  One of the most popular online action games of...
# 8  Play the world's number 1 online action game. ...
#
#                                  supported_languages  ...  \
# 0                                            English  ...
# 1  English, French, German, Italian, Spanish - Sp...  ...
# 2  English<strong>*</strong>, French<strong>*</st...  ...
# 3  English, French, German, Italian, Spanish - Sp...  ...
# 4                    English, French, German, Korean  ...
# 5  English, French, German, Italian, Spanish - Sp...  ...
# 6  English, French, German, Italian, Spanish - Spain  ...
# 7  English, French, German, Italian, Spanish - Sp...  ...
# 8  English<strong>*</strong>, French<strong>*</st...  ...
#
#                                      capsule_imagev5  \
# 0  https://cdn.akamai.steamstatic.com/steam/apps/...
# 1  https://cdn.akamai.steamstatic.com/steam/apps/...
# 2  https://cdn.akamai.steamstatic.com/steam/apps/...
# 3  https://cdn.akamai.steamstatic.com/steam/apps/...
# 4  https://cdn.akamai.steamstatic.com/steam/apps/...
# 5  https://cdn.akamai.steamstatic.com/steam/apps/...
# 6  https://cdn.akamai.steamstatic.com/steam/apps/...
# 7  https://cdn.akamai.steamstatic.com/steam/apps/...
# 8  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                        website pc_requirements mac_requirements  \
# 0                         None              []               []
# 1                         None             NaN               []
# 2    http://www.half-life.com/             NaN              NaN
# 3                         None             NaN              NaN
# 4                         None             NaN              NaN
# 5                         None             NaN              NaN
# 6  http://www.dayofdefeat.com/             NaN              NaN
# 7                         None             NaN              NaN
# 8                         None             NaN              NaN
#
#   linux_requirements                            pc_requirements.minimum  \
# 0                 []                                                NaN
# 1                 []  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 2                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 3                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 4                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 5                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 6                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 7                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
# 8                NaN  \r\n\t\t\t<p><strong>Minimum:</strong> 500 mhz...
#
#   controller_support       dlc  \
# 0                NaN       NaN
# 1                NaN       NaN
# 2               full  [323130]
# 3                NaN       NaN
# 4                NaN       NaN
# 5                NaN       NaN
# 6                NaN       NaN
# 7                NaN       NaN
# 8                NaN       NaN
#
#                             mac_requirements.minimum  \
# 0                                                NaN
# 1                                                NaN
# 2  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 3  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 4  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 5  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 6  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 7  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
# 8  Minimum: OS X  Snow Leopard 10.6.3, 1GB RAM, 4...
#
#                           linux_requirements.minimum
# 0                                                NaN
# 1                                                NaN
# 2  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 3  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 4  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 5  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 6  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 7  Minimum: Linux Ubuntu 12.04, Dual-core from In...
# 8  Minimum: Linux Ubuntu 12.04, Dual-core from In...
#
# [9 rows x 22 columns]

# %%
import json

# Salvar a lista em formato JSON
with open('app_details.json', 'w', encoding='utf-8') as f:
    json.dump(app_details_list, f, ensure_ascii=False, indent=4)

print("Lista salva como 'app_details.json'")
# Out:
# Lista salva como 'app_details.json'
